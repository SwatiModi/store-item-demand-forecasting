# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv('train.csv', parse_dates=['date'])
test = pd.read_csv('test.csv', parse_dates=['date'])
sample_sub = pd.read_csv('sample_submission.csv')

# %%
print('Train shape:{}, Test shape:{}'.format(train.shape, test.shape))
# Out:
# Train shape:(913000, 4), Test shape:(45000, 4)

# %%
train.head()
# Out:
#         date  store  item  sales
# 0 2013-01-01      1     1     13
# 1 2013-01-02      1     1     11
# 2 2013-01-03      1     1     14
# 3 2013-01-04      1     1     13
# 4 2013-01-05      1     1     10

# %%
print("number of unique items :",train.item.nunique())
print("number of unique store :",train.store.nunique())
# Out:
# number of unique items : 50
# number of unique store : 10

# %%
train.head()
# Out:
#         date  store  item  sales
# 0 2013-01-01      1     1     13
# 1 2013-01-02      1     1     11
# 2 2013-01-03      1     1     14
# 3 2013-01-04      1     1     13
# 4 2013-01-05      1     1     10

# %%
train.tail()
# Out:
#              date  store  item  sales
# 912995 2017-12-27     10    50     63
# 912996 2017-12-28     10    50     59
# 912997 2017-12-29     10    50     74
# 912998 2017-12-30     10    50     62
# 912999 2017-12-31     10    50     82

# %%
train[train.item == 1]['sales'].sum()
# Out:
# 401384

# %%
store_1_total_sales = train[train.store == 1]['sales'].sum()

# %%
store_2_total_sales = train[train.store == 2]['sales'].sum()

# %%
store_3_total_sales = train[train.store == 3]['sales'].sum()

# %%
store_4_total_sales = train[train.store == 4]['sales'].sum()

# %%
store_5_total_sales = train[train.store == 5]['sales'].sum()

# %%
sales_1 = train[train.store == 1]['sales'].sort_index(ascending = True)

# %%
sales_2 = train[train.store == 2]['sales'].sort_index(ascending = True)

# %%
sales_3 = train[train.store == 3]['sales'].sort_index(ascending = True)

# %%
sales_4 = train[train.store == 4]['sales'].sort_index(ascending = True)

# %%
sales_5 = train[train.store == 5]['sales'].sort_index(ascending = True)

# %%
f, (ax1, ax2, ax3, ax4, ax5) = plt.subplots(5, figsize = (12, 13))
c = '#386B7F'

sales_1.plot(color = c, ax = ax1)
sales_2.plot(color = c, ax = ax2)
sales_3.plot(color = c, ax = ax3)
sales_4.plot(color = c, ax = ax4)
sales_5.plot(color = c, ax = ax5)

# %%
train['dayofmonth'] = train.date.dt.day
train['dayofyear'] = train.date.dt.dayofyear
train['dayofweek'] = train.date.dt.dayofweek
train['month'] = train.date.dt.month
train['year'] = train.date.dt.year
train['weekofyear'] = train.date.dt.weekofyear
train.head()
# Out:
#         date  store  item  sales  dayofmonth  dayofyear  dayofweek  month  \
# 0 2013-01-01      1     1     13           1          1          1      1
# 1 2013-01-02      1     1     11           2          2          2      1
# 2 2013-01-03      1     1     14           3          3          3      1
# 3 2013-01-04      1     1     13           4          4          4      1
# 4 2013-01-05      1     1     10           5          5          5      1
#
#    year  weekofyear
# 0  2013           1
# 1  2013           1
# 2  2013           1
# 3  2013           1
# 4  2013           1

# %%
train.head()
# Out:
#         date  store  item  sales  dayofmonth  dayofyear  dayofweek  month  \
# 0 2013-01-01      1     1     13           1          1          1      1
# 1 2013-01-02      1     1     11           2          2          2      1
# 2 2013-01-03      1     1     14           3          3          3      1
# 3 2013-01-04      1     1     13           4          4          4      1
# 4 2013-01-05      1     1     10           5          5          5      1
#
#    year  weekofyear
# 0  2013           1
# 1  2013           1
# 2  2013           1
# 3  2013           1
# 4  2013           1

# %%
year_2013 = train[train['year']==2013]
year_2014 = train[train['year']==2014]
year_2015 = train[train['year']==2015]
year_2016 = train[train['year']==2016]
year_2017 = train[train['year']==2017]

# %%
len(year_2013)
# Out:
# 182500

# %%
len(train)
# Out:
# 913000

# %%
year_2013.groupby('dayofmonth')['sales'].mean().plot.bar()

# %%
year_2014.groupby('dayofmonth')['sales'].mean().plot.bar()

# %%
year_2013.groupby('dayofweek')['sales'].mean().plot.bar()
plt.title('day of week vs mean sales')
# Out:
# Text(0.5,1,'day of week vs mean sales')

# %%
train.groupby('dayofweek')['sales'].mean().plot.bar()

# %% [markdown]
# We can see here that the sales have an increasing trend in sales weekwise

# %%
def weekend(row):
    if row == 5 or row == 6:
        return 1
    else:
        return 0

# %%
temp2 = train['dayofweek'].apply(weekend)

# %%
train['weekend'] = temp2

# %%
train.groupby('weekend')['sales'].mean().plot.bar()

# %% [markdown]
# ##### Visualization of store items individually

# %%
store_1 = train[train.store==1]['sales'].sort_index(ascending = True)

# %%
store_1.plot()

# %%
store_1_2013 = train[(train.store==1) & (train.year == 2013)]['sales'].sort_index(ascending = True)

# %%
store_1_2013.plot()

# %%
store_1_2013_item1 = train[(train.store==1) & (train.year == 2013) & (train.item==1)]['sales'].sort_index(ascending = True)

# %%
store_1_2013_item1.plot()

# %%
store_1_2013_item2= train[(train.store==1) & (train.year == 2013) & (train.item==2)]['sales'].sort_index(ascending = True)

# %%
store_1_2013_item2.plot()

# %%
for i in range(1,11):
    month_df = train[train.store==i].resample('M',on='date').sum()
    x= np.array(month_df.index)
    y=np.array(month_df.sales)
    plt.plot(x,y,label = 'store %s' % i)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.title("Total sales by month")
plt.show()

# %%
store_item_df = train.groupby(['store','item']).sum()
matrixStoreItem = np.zeros((10,50))
for i in range(1,11):
    for j in range(1,51):
        matrixStoreItem[i-1,j-1] = store_item_df.loc[i,j].sales

plt.figure(figsize=(50,10))
ax = sns.heatmap(matrixStoreItem,cmap='Reds')
plt.xlabel("Item",fontsize = 25)
plt.ylabel("Store",fontsize=25)
plt.title("Store/ Item sales heatmap",fontsize=35)
# Out:
# Text(0.5,1,'Store/ Item sales heatmap')

# %%
plt.close('all')
item_df = train.groupby(['item']).mean()
item_df.sort_values('sales',ascending=True,inplace=True)
x = item_df.index
y = item_df.sales
plt.figure(figsize=(20,10))
sns.barplot(x=x, y=y, order=x)
plt.xlabel("Item",fontsize = 25)
plt.ylabel("Mean sales",fontsize=25)
plt.title("Mean sales by items",fontsize=35)
plt.show()
